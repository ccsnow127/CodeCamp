# %%
a, b = ["a", "b", "c"], [1, 2, 3]
a.append("d")
print(a)#['a', 'b', 'c', 'd']
# print(a.append("d"))#None
a.extend(b)
print(a)#['a', 'b', 'c', 'd', 1, 2, 3]
# print(a.extend(b))#None
# Out:
# ['a', 'b', 'c', 'd']
# ['a', 'b', 'c', 'd', 1, 2, 3]

# %%
#['a', 'b', 'c', 'd', 1, 2, 3]
del a[-1]
print(a)
#['a', 'b', 'c', 'd', 1, 2]
# Out:
# ['a', 'b', 'c', 'd', 1, 2]

# %%
a.pop(0)
# Out:
# 'a'
